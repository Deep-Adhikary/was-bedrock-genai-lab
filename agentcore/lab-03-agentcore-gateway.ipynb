# %% [markdown]
# # Lab 3: Securely connect tools to your Agent with AgentCore Gateway
#
# ## Overview
#
# In this Lab, you will learn how to integrate tools available in your organization with the Customer Support Agent using the Amazon Bedrock Gateway.
#
# The [Model Context Protocol (MCP)](https://modelcontextprotocol.io/docs/getting-started/intro) is an open protocol that standardizes how applications provide tools and context to Large Language Models (LLMs).
#
# With [Amazon Bedrock Agent Core Gateway](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/gateway.html), developers can convert APIs, Lambda functions, and existing services into MCP-compatible tools and make them available to agents through Gateway endpoints with just a few lines of code.
#
#
# **Workshop Journey:**
#
# - **Lab 1 (Done):** Create Agent Prototype - Built a functional customer support agent
# - **Lab 2 (Done):** Enhance with Memory - Added conversation context and personalization
# - **Lab 3 (Current):** Scale with Gateway & Identity - Shared tools across agents securely
# - **Lab 4:** Deploy to Production - Used AgentCore Runtime with observability
# - **Lab 5:** Build User Interface - Create a customer-facing application
#
#
# ### Why AgentCore Gateway & Tool Sharing Matter
#
# Current State (Lab 1-2): Each agent has its own copy of tools. I practice that is not scalable and leads to:
#
# - Code duplication across different agents
# - Inconsistent tool behavior and maintenance overhead
# - No centralized security or access control
# - Difficulty scaling to multiple use cases
#
# After this lab, we will have centralized, reusable tools that can serve:
#
# - Customer Support Agent (our current use case)
# - Sales Agent (needs same product info and customer data)
# - Inventory Agent (needs same product info and warranty checking)
# - Returns Processing Agent (needs return policies and customer profiles)
#
# and other use cases.
#
# ### Adding secure authentication with AgentCore Identity
#
# Additionally, AgentCore Gateway requires you to securely authenticate both inbound and outbound connections. [AgentCore Identity](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/identity.html) provides seamless agent identity and access management across AWS services and third-party applications such as Slack and Zoom while supporting any standard identity providers such as Okta, Entra, and Amazon Cognito. In this lab we will see how AgentCore Gateway integrates with AgentCore Identity to provide secure connections via inbound and outbound authentication.
#
# For the inbound authentication, the AgentCore Gateway analyzes the OAuth token passed during invocation to decide allow or deny the access to a tool in the gateway. If a tool needs access to external resources, the AgentCore Gateway can use outbound authentication via API Key, IAM or OAuth Token to allow or deny the access to the external resource.
#
# During the inbound authorization flow, an agent or the MCP client calls an MCP tool in the AgentCore Gateway adding an OAuth access token (generated from the user’s IdP). AgentCore Gateway then validates the OAuth access token and performs inbound authorization.
#
# If the tool running in AgentCore Gateway needs to access external resources, OAuth will retrieve credentials of downstream resources using the resource credential provider for the Gateway target. AgentCore Gateway pass the authorization credentials to the caller to get access to the downstream API.
#
#
# ## Architecture for Lab 3
#
# <div style="text-align:left">
#     <img src="images/architecture_lab3_gateway.png" width="75%"/>
# </div>
#
# *Web search tool is now centralized in AgentCore Gateway with secure identity-based access control. Multiple agents and use cases can share the same tool securely. We will also reuse the `check_warranty()` tool built for other applications and add the `web_search()` tool for use within other applications. `get_product_info()`, `get_return_policy()`, and `get_technical_support` remain as local tools as they are specific to the customer support use case*
#
# ### Key Features
# - **Seamlessly integrate AWS Lambda functions:** This example shows how to integrate your Agent with existing AWS Lambda functions to check the warranty of an item and to get the customer profile using Amazon Bedrock AgentCore Gateway.
# - **Secure your Gateway endpoint with Inbound Auth**: Only an Agent providing a valid JWT token can connect to the endpoint to use the tools
# - **Configure the Agent to use the MCP endpoint**: The Agent gets a valid JWT token and uses it to connect to the MCP endpoint provided by AgentCore Gateway
#
# ## Prerequisites
#
# * Complete Lab 2 Add memory to the Customer Support Agent
# * **IMPORTANT:** Infrastructure deployed from Lab 1 (prereq.sh script)
#     - If you skipped Lab 1's infrastructure setup, go back and run the prereq.sh cell
#     - This lab requires:
#         - AWS Lambda function
#         - AWS Lambda Execution IAM Role
#         - AgentCore Gateway IAM Role
#         - DynamoDB tables used by the AWS Lambda function
#         - Cognito User Pool and User Pool Client

# %% [markdown]
# ## Step 1: Import required libraries

# %%
# Import libraries
from strands import Agent
from strands.models import BedrockModel
from strands.tools.mcp import MCPClient
import os
import sys
import boto3
import json
from mcp.client.streamable_http import streamablehttp_client
import requests

from scripts.utils import get_ssm_parameter, put_ssm_parameter, get_cognito_client_secret, call_with_retry

sts_client = boto3.client('sts')

# Get AWS account details
REGION = boto3.session.Session().region_name

gateway_client = boto3.client(
    "bedrock-agentcore-control",
    region_name=REGION,
)

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!
# /home/participant/.local/lib/python3.13/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.1.0)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# ## Step 2: Give our agent a tool to access existing customer data
# AgentCore Gateway simplifies agent tool integration in three key ways:
#
# 1. Universal MCP Support: Instantly make your tools compatible with any agent framework by exposing them through AgentCore Gateway's MCP standard
#
# 1. Simple REST Integration: Transform existing REST services into agent tools by just adding them as AgentCore Gateway targets
#
# 1. Lambda Flexibility: Expose Lambda functions as MCP endpoints that can call any API - demonstrated here with a function that checks warranty status
#
#     AgentCore Gateway populates the Lambda context with the name of the tool to invoke:
#
#     ```
#     extended_tool_name = context.client_context.custom["bedrockAgentCoreToolName"] //
#     resource = extended_tool_name.split("___")[1]
#     ```
#
#     Parameters passed to the tool are provided in the Lambda event, e.g.f:
#
#     ```
#     event.get("serial_number")
#     ```
#
#     See the [Lambda function](./prerequisite/lambda/python/lambda_function.py) code for more details.

# %% [markdown]
# ## Step 3 Convert your web search tool to MCP
# Now that we are developing an MCP server using AgentCore Gateway, we can MCP-ify any tools which we think we'll use for multiple Agents. One of these tools might be a web search tool like we built in Lab 1. As a result, we also converted the web search tool from Lab 1 into a Lambda tool within our AgentCore Gateway:
#
# [Web search Lambda](./prerequisite/lambda/python/web_search.py)

# %%
# !cat prerequisite/lambda/python/web_search.py
# Out:
# from ddgs import DDGS
#
#
# def web_search(keywords: str, region: str = "us-en", max_results: int = 5) -> str:
#     """Search the web for updated information.
#
#     Args:
#         keywords (str): The search query keywords.
#         region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc.
#         max_results (int): The maximum number of results to return.
#
#     Returns:
#         List of dictionaries with search results.
#     """
#     try:
#         results = DDGS().text(keywords, region=region, max_results=max_results)
#         return results if results else "No results found."
#     except Exception as e:
#         return f"Search error: {str(e)}"
#
#
# print("✅ Web search tool ready")

# %% [markdown]
# ## Step 4 Create your function definition metadata
# Lastly, we need to write tool schema which describes the tools implemented by your Lambda function.
#
# This file has been already defined in [prerequisite/lambda/api_spec.json](./prerequisite/lambda/api_spec.json)

# %%
# !cat ./prerequisite/lambda/api_spec.json
# Out:
# [
#     {
#         "name": "check_warranty_status",
#         "description": "Check the warranty status of a product using its serial number and optionally verify via email",
#         "inputSchema": {
#             "type": "object",
#             "properties": {
#                 "serial_number": {
#                     "type": "string"
#                 },
#                 "customer_email": {
#                     "type": "string"
#                 }
#             },
#             "required": [
#                 "serial_number"
#             ]
#         }
#     },
#     {
#         "name": "web_search",
#         "description": "Search the web for updated information using DuckDuckGo",
#         "inputSchema": {
#             "type": "object",
#             "properties": {
#                 "keywords": {
#                     "type": "string",
#                     "description": "The search query keywords"
#                 },
#                 "region": {
#                     "type": "string",
#                     "description": "The search region (e.g., us-en, uk-en, ru-ru)"
#                 },
#                 "max_results": {
#                     "type": "integer",
#                     "description": "The maximum number of results to return"
#                 }
#             },
#             "required": [
#                 "keywords"
#             ]
#         }
#     }
# ]

# %% [markdown]
# ## Step 5. Create your AgentCore Gateway
#
# Now let's create the AgentCore Gateway to expose the Lambda function as MCP-compatible endpoint.
#
# To validate the callers authorized to invoke our tools we need to configure the Inbound Auth.
#
# Inbound Auth works using OAuth authorization, the standard for MCP servers. With OAuth the client application must authenticate with the OAuth authorizer before using the Gateway. Your client would receive an access token which is used at runtime.
#
# You need to specify an OAuth discovery server and client IDs. The Cloudformation provided with the workshop already provisioned the Cognito UserPool and UserPoolClient and it stored the discovery URL and the Client ID in dedicated SSM parameters.

# %%
gateway_name = "customersupport-gw"

auth_config = {
    "customJWTAuthorizer": {
        "allowedClients": [
            get_ssm_parameter("/app/customersupport/agentcore/machine_client_id")
        ],
        "discoveryUrl": get_ssm_parameter("/app/customersupport/agentcore/cognito_discovery_url")
    }
}

try:
    # create new gateway
    print(f"Creating gateway in region {REGION} with name: {gateway_name}")

    create_response = gateway_client.create_gateway(
        name=gateway_name,
        roleArn= get_ssm_parameter("/app/customersupport/agentcore/gateway_iam_role"),
        protocolType="MCP",
        authorizerType="CUSTOM_JWT",
        authorizerConfiguration=auth_config,
        description="Customer Support AgentCore Gateway",
    )

    gateway_id = create_response["gatewayId"]

    gateway = {
        "id": gateway_id,
        "name": gateway_name,
        "gateway_url": create_response["gatewayUrl"],
        "gateway_arn": create_response["gatewayArn"],
    }
    put_ssm_parameter("/app/customersupport/agentcore/gateway_id", gateway_id)

    print(f"✅ Gateway created successfully with ID: {gateway_id}")

except Exception as e:
    # If gateway exists, collect existing gateway ID from SSM
    existing_gateway_id = get_ssm_parameter("/app/customersupport/agentcore/gateway_id")
    print(f"Found existing gateway with ID: {existing_gateway_id}")
    
    # Get existing gateway details
    gateway_response = gateway_client.get_gateway(gatewayIdentifier=existing_gateway_id)
    gateway = {
        "id": existing_gateway_id,
        "name": gateway_response["name"],
        "gateway_url": gateway_response["gatewayUrl"],
        "gateway_arn": gateway_response["gatewayArn"],
    }
    gateway_id = gateway['id']
# Out:
# Creating gateway in region us-east-1 with name: customersupport-gw
# ✅ Gateway created successfully with ID: customersupport-gw-e6hmsi5c6o

# %% [markdown]
# ## Step 6. Add the Lambda function Target
# Now we will use the previously defined function definitions from [prerequisite/lambda/api_spec.json](./prerequisite/lambda/api_spec.json) to create a Lambda target within our Agent Gateway. This will define the tools that your gateway will host.
#
# Gateway allows you to attach multiple targets to a Gateway and you can change the targets / tools attached to a gateway at any point. Each target can have its own credential provider, but Gateway becomes a single MCP URL enabling access to all of the relevant tools for an agent across myriad APIs.

# %%
def load_api_spec(file_path: str) -> list:
    with open(file_path, "r") as f:
        data = json.load(f)
        
    if not isinstance(data, list):
        raise ValueError("Expected a list in the JSON file")
    return data

try:
    api_spec_file = "./prerequisite/lambda/api_spec.json"

    # Validate API spec file exists
    if not os.path.exists(api_spec_file):
        print(f"❌ API specification file not found: {api_spec_file}")
        sys.exit(1)

    api_spec = load_api_spec(api_spec_file)
 
    # Use Cognito for Inbound OAuth to our Gateway
    lambda_target_config = {
        "mcp": {
            "lambda": {
                "lambdaArn": get_ssm_parameter("/app/customersupport/agentcore/lambda_arn"),
                "toolSchema": {"inlinePayload": api_spec},
            }
        }
    }


    # Create gateway target
    credential_config = [{"credentialProviderType": "GATEWAY_IAM_ROLE"}]

    create_target_response = gateway_client.create_gateway_target(
        gatewayIdentifier=gateway_id,
        name="LambdaUsingSDK",
        description="Lambda Target using SDK",
        targetConfiguration=lambda_target_config,
        credentialProviderConfigurations=credential_config,
    )

    print(f"✅ Gateway target created: {create_target_response['targetId']}")

except Exception as e:
    print(f"❌ Error creating gateway target: {str(e)}")
# Out:
# ✅ Gateway target created: T2XZRTMKQW

# %% [markdown]
# ## Step 7: Add our new MCP-based tools to our support agent
# Here we integrate our authentication token from Cognito into an MCPClient from Strands SDK to create an MCP Server object to integrate with our Strands Agent

# %%
def get_token(client_id: str, client_secret: str, scope_string: str, url: str) -> dict:
    try:
        headers = {"Content-Type": "application/x-www-form-urlencoded"}
        data = {
            "grant_type": "client_credentials",
            "client_id": client_id,
            "client_secret": client_secret,
            "scope": scope_string,

        }
        response = requests.post(url, headers=headers, data=data)
        response.raise_for_status()
        return response.json()

    except requests.exceptions.RequestException as err:
        return {"error": str(err)}

# %% [markdown]
# ## Step 7.1. Set up a secure MCP client object

# %%
gateway_access_token = get_token(
    get_ssm_parameter("/app/customersupport/agentcore/machine_client_id"),
    get_cognito_client_secret(),
    get_ssm_parameter("/app/customersupport/agentcore/cognito_auth_scope"),
    get_ssm_parameter("/app/customersupport/agentcore/cognito_token_url"))

print(f"Gateway Endpoint - MCP URL: {gateway['gateway_url']}")

# Set up MCP client
mcp_client = MCPClient(
    lambda: streamablehttp_client(
        gateway['gateway_url'],
        headers={"Authorization": f"Bearer {gateway_access_token['access_token']}"},
    )
)
# Out:
# Gateway Endpoint - MCP URL: https://customersupport-gw-e6hmsi5c6o.gateway.bedrock-agentcore.us-east-1.amazonaws.com/mcp

# %% [markdown]
# ## Step 7.2. Access tools in our agent using our MCP client
# Now we will create our Strands Agent using the AgentCore Gateway we built along with the resources from previous labs. Our agent now uses a mix of local tools via our Strands Agent and MCP tools via AgentCore Gateway

# %%
from lab_helpers.lab1_strands_agent import get_product_info, get_return_policy, get_technical_support, SYSTEM_PROMPT
from lab_helpers.lab2_memory import CustomerSupportMemoryHooks,create_or_get_memory_resource 
import uuid
from bedrock_agentcore.memory import MemoryClient

memory_client = MemoryClient(region_name=REGION)

memory_id = create_or_get_memory_resource()
SESSION_ID = str(uuid.uuid4())
CUSTOMER_ID = "customer_001"
memory_hooks = CustomerSupportMemoryHooks(memory_id, memory_client, CUSTOMER_ID, SESSION_ID)

# Initialize the Bedrock model
model_id = "us.anthropic.claude-sonnet-4-20250514-v1:0"
model = BedrockModel(
    model_id=model_id,
    temperature=0.3,  # Balanced between creativity and consistency
    region_name=REGION
)

try:
    mcp_client.start()
except Exception as e:
    print(f"Error initializing agent: {str(e)}")

tools = (
            [
                get_product_info,
                get_return_policy,
                get_technical_support
            ]
            + mcp_client.list_tools_sync()
        )

# Create the customer support agent
agent = Agent(
    model=model,
    tools=tools,
    hooks=[memory_hooks],
    system_prompt=SYSTEM_PROMPT
)

print("✅ Customer support agent created successfully!")
# Out:
# ✅ Customer support agent created successfully!

# %% [markdown]
# ## Step 8: Test the agent with MCP tool access to existing APIs”
#
# Let's test our agent with sample queries to ensure all features work correctly.

# %%
test_prompts = [
    # Warranty Checks
    "List all of your tools",
    "I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?",
    "I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.",
    "What are the warranty support guidelines?",
    "How can I fix Lenovo Thinkpad with a blue screen",
    "Tell me detailed information about the technical documentation on installing a new CPU"
]

# Function to test the agent
def test_agent_responses(agent, prompts):
    for i, prompt in enumerate(prompts, 1):
        print(f"\nTest Case {i}: {prompt}")
        print("-" * 50)
        try:
            call_with_retry(lambda: agent(prompt))
        except Exception as e:
            print(f"Error: {str(e)}")
        print("-" * 50)

# Run the tests
test_agent_responses(agent, test_prompts)

print("\\n✅ Basic testing completed!")
# Out:
# Test Case 1: List all of your tools
# --------------------------------------------------
# Here are all the tools I have available to assist you:
#
# ## Available Customer Support Tools
#
# 1. **get_product_info(product_type)**
#    - Get detailed technical specifications and information for electronics products
#    - Covers products like: laptops, smartphones, headphones, monitors, etc.
#    - Provides warranty details, features, and policies
#
# 2. **get_return_policy(product_category)**
#    - Get return policy information for specific product categories
#    - Categories include: smartphones, laptops, accessories, etc.
#    - Shows timeframes and return conditions
#
# 3. **get_technical_support(issue_description)**
#    - Get technical support assistance for specific issues
#    - Helps troubleshoot problems with electronics
#
# 4. **check_warranty_status(serial_number, customer_email)**
#    - Check warranty status using product serial number
#    - Can verify warranty via customer email (optional)
#
# 5. **web_search(keywords, max_results, region)**
#    - Search for current technical documentation and updated information
#    - Useful for finding the latest specs, reviews, or technical details
#    - Can search in different regions
#
# Based on your preferences for competitive FPS gaming, video editing on MacBook Pro, and interest in ThinkPad models, I can help you with:
# - Gaming headphone specifications and recommendations
# - Technical support for MacBook Pro overheating issues
# - Information about ThinkPad laptops
# - Product comparisons and technical details
#
# How can I assist you today? Would you like information about any specific products or need help with a technical issue?--------------------------------------------------
#
# Test Case 2: I bought an iphone 14 last month. I don't like it because it heats up. How do I solve it?
# --------------------------------------------------
# I can help you with the iPhone 14 heating issue! Let me get some technical support information for you.
# Tool #1: get_technical_support
# Successfully retrieved KB ID: D39IAEEYYQ
# Let me also get specific product information about smartphones to provide you with more targeted solutions:
# Tool #2: get_product_info
# Based on the technical support information, here are several solutions for your iPhone 14 heating issue:
#
# ## Immediate Solutions to Try:
#
# ### **Battery & Performance Optimization:**
# - **Adjust screen brightness** - Lower brightness reduces heat generation
# - **Enable Low Power Mode** when not needed for intensive tasks
# - **Manage background app refresh** - Turn off for apps you don't need updating constantly
# - **Configure location services** - Disable for apps that don't need location access
#
# ### **App & Usage Management:**
# - **Close resource-intensive apps** when not in use
# - **Check for app updates** - Outdated apps can cause excessive CPU usage
# - **Restart your iPhone** regularly to clear temporary files
# - **Update to the latest iOS version** - Apple often includes thermal management improvements
#
# ### **Environmental Factors:**
# - **Remove case temporarily** to see if it improves cooling
# - **Avoid direct sunlight** and hot environments while using the device
# - **Don't charge while using intensive apps** (gaming, video streaming)
#
# ## If the Problem Persists:
#
# Since you bought it last month, your iPhone 14 is definitely under the **1-year manufacturer warranty**. If the heating issue continues after trying these solutions, you may have a defective unit that qualifies for warranty replacement.
#
# **Next Steps:**
# 1. Try the optimization steps above for a few days
# 2. If heating persists, contact Apple support for warranty diagnosis
# 3. Keep your proof of purchase ready for any warranty claims
#
# Would you like me to help you check the return policy for smartphones, or do you need assistance with any specific settings on your iPhone 14?--------------------------------------------------
#
# Test Case 3: I have a Gaming Console Pro device , I want to check my warranty status, warranty serial number is MNO33333333.
# --------------------------------------------------
# I'll check the warranty status for your Gaming Console Pro using the serial number you provided.
# Tool #3: LambdaUsingSDK___check_warranty_status
# ## Warranty Status for Your Gaming Console Pro
#
# **Serial Number:** MNO33333333
#
# ### Current Status: ❌ **EXPIRED**
# - **Purchase Date:** November 25, 2023
# - **Warranty End Date:** November 25, 2024
# - **Expired:** 479 days ago (approximately 1 year and 4 months)
#
# ### Original Coverage Included:
# - Controller issues
# - Overheating protection
# - Hard drive replacement
#
# ## Your Options Now:
#
# ### **1. Extended Warranty Plans**
# Extended warranty options may still be available for your Gaming Console Pro. These typically cover:
# - Hardware repairs and replacements
# - Technical support
# - Sometimes accidental damage protection
#
# ### **2. Out-of-Warranty Repair Services**
# Since your warranty has expired, any repairs would be:
# - Quote provided before service begins
# - You pay for parts and labor
# - Express service available for additional fee
#
# ### **3. Upgrade Consideration**
# Given that you're into competitive FPS gaming and your console is now out of warranty, you might want to consider if upgrading would be more cost-effective than expensive repairs.
#
# **Next Steps:**
# - Contact our support team for extended warranty pricing
# - Get a repair quote if you're experiencing specific issues
# - Consider upgrade options if repair costs are high
#
# Is your Gaming Console Pro currently experiencing any issues, or were you just checking the warranty status? I can help you explore your best options based on what's happening with your device.--------------------------------------------------
#
# Test Case 4: What are the warranty support guidelines?
# --------------------------------------------------
# Let me get you the comprehensive warranty support guidelines from our system.
# Tool #4: get_technical_support
# Successfully retrieved KB ID: D39IAEEYYQ
# # Warranty Support Guidelines
#
# ## 🛡️ **WARRANTY COVERAGE**
#
# ### **What's Covered (Full Coverage):**
# - **Manufacturing defects** - Hardware failures due to production issues
# - **Software issues** - If not caused by user actions
# - **Component failures** - During normal use within warranty period
#
# ### **What's NOT Covered:**
# - **Normal wear and tear** - Expected degradation over time
# - **Accidental damage** - Drops, spills, physical damage
# - **Water damage** - Generally not covered (check IP rating for exceptions)
# - **User-caused software issues** - Malware, unauthorized modifications
#
# ---
#
# ## 📋 **WARRANTY CLAIMS PROCESS**
#
# ### **Step-by-Step Process:**
# 1. **Gather Documentation**
#    - Proof of purchase (receipt/invoice)
#    - Product serial number
#    - Description of the issue
#
# 2. **Contact Technical Support**
#    - Get professional diagnosis
#    - Verify warranty coverage
#    - Receive troubleshooting guidance
#
# 3. **Complete Warranty Claim Form**
#    - Provide all required information
#    - Submit supporting documentation
#
# 4. **Secure Packaging & Shipping**
#    - Use original packaging when possible
#    - Follow provided shipping instructions
#
# 5. **Track Repair Status**
#    - Monitor progress through online portal
#    - Receive updates on repair timeline
#
# ---
#
# ## 🔧 **SERVICE OPTIONS**
#
# ### **In-Warranty Repairs:**
# - ✅ **FREE parts and labor**
# - ✅ **No diagnostic fees**
# - ✅ **Return shipping included**
#
# ### **Out-of-Warranty Repairs:**
# - 💰 **Quote provided before service**
# - 🔧 **Professional repair services**
# - ⚡ **Express service available** (additional fee)
#
# ### **Business Customers:**
# - 🏢 **On-site service available**
# - 📞 **Dedicated business support**
# - 🚀 **Priority service options**
#
# ---
#
# ## 🛡️ **EXTENDED WARRANTY PLANS**
#
# ### **Additional Protection Options:**
# - **Accidental Damage Protection** - Covers drops, spills, etc.
# - **Extended Coverage Periods** - Beyond standard warranty
# - **Premium Technical Support** - Priority assistance
# - **Replacement Device Programs** - Faster resolution options
#
# ---
#
# ## 📞 **SUPPORT CHANNELS**
#
# ### **24/7 Support:**
# - 💬 **Online Chat** - Instant assistance
# - 📧 **Email Support** - 24-hour response time
#
# ### **Business Hours Support:**
# - ☎️ **Phone Support** - Direct technical assistance
# - 📹 **Video Troubleshooting** - Appointment-based visual support
#
# ---
#
# ## 💡 **Pro Tips for Warranty Claims:**
#
# 1. **Keep Your Receipt** - Always save proof of purchase
# 2. **Register Your Product** - Helps expedite warranty claims
# 3. **Document Issues** - Take photos/videos of problems
# 4. **Try Basic Troubleshooting** - May resolve issues quickly
# 5. **Contact Support Early** - Don't wait until warranty expires
#
# Given your MacBook Pro order #MB-78432 that's still under warranty, you're covered for any manufacturing defects or hardware issues. For your overheating during video editing, this would likely qualify for warranty service if it's due to a hardware defect.
#
# Would you like me to help you with a specific warranty claim, or do you need information about warranty coverage for a particular product category?--------------------------------------------------
#
# Test Case 5: How can I fix Lenovo Thinkpad with a blue screen
# --------------------------------------------------
# I'll help you troubleshoot the blue screen issue on your Lenovo ThinkPad. Let me get technical support information for this problem.
# Tool #5: get_technical_support
# Successfully retrieved KB ID: D39IAEEYYQ
# Let me also get specific laptop product information to provide more targeted solutions:
# Tool #6: get_product_info
# # 🔧 **ThinkPad Blue Screen (BSOD) Troubleshooting Guide**
#
# ## **Immediate Steps to Try:**
#
# ### **1. Safe Mode Boot & Basic Fixes**
# - **Restart and press F8** repeatedly during boot to access Advanced Boot Options
# - **Select "Safe Mode"** to boot with minimal drivers
# - **Run Windows Update** to install latest patches
# - **Update all drivers**, especially graphics and chipset drivers
#
# ### **2. Check for Overheating Issues**
# Since you mentioned overheating with your MacBook Pro, this could be relevant:
# - **Clean vents and fans** - Use compressed air to remove dust buildup
# - **Monitor temperature levels** - Use tools like HWiNFO64
# - **Ensure proper ventilation** - Keep laptop on hard, flat surfaces
# - **Check for unusual fan noise** - May indicate hardware issues
#
# ### **3. Hardware Diagnostics**
# - **Run built-in Lenovo diagnostics** - Usually accessible at boot (F10 or F12)
# - **Check RAM** - Run Windows Memory Diagnostic (mdsched.exe)
# - **Test hard drive health** - Use CHKDSK or built-in disk tools
# - **Verify all connections** - Reseat RAM and storage if comfortable doing so
#
# ## **Advanced Troubleshooting:**
#
# ### **Driver-Related Solutions:**
# - **Boot into Safe Mode** and uninstall recently installed drivers
# - **Roll back graphics drivers** to previous stable version
# - **Update BIOS/UEFI** from Lenovo's support website
# - **Check Device Manager** for any devices with error indicators
#
# ### **System File Repairs:**
# - **Run SFC scan**: Open Command Prompt as admin, type `sfc /scannow`
# - **Run DISM**: `DISM /Online /Cleanup-Image /RestoreHealth`
# - **Check Event Viewer** for specific error codes that caused the BSOD
#
# ### **Linux Compatibility Note:**
# Since you prefer good Linux compatibility, if Windows continues having issues, ThinkPads generally have excellent Linux support. You could:
# - **Create a Linux live USB** to test if hardware works properly
# - **Consider dual-boot setup** for better stability
# - **Check Lenovo's Linux certification** for your specific ThinkPad model
#
# ## **When to Seek Professional Help:**
#
# ### **Contact Support If:**
# - Blue screens persist after trying above steps
# - Error occurs during hardware diagnostics
# - Multiple different BSOD error codes appear
# - System won't boot even in Safe Mode
#
# ### **Warranty Coverage:**
# Your ThinkPad likely has a **1-year manufacturer warranty** that covers:
# - Hardware defects causing system crashes
# - Memory failures
# - Storage device issues
# - Motherboard problems
#
# ## **Prevention Tips:**
# - **Keep 15-20% disk space free**
# - **Regular driver updates**
# - **Monthly system maintenance**
# - **Monitor system temperatures**
# - **Regular data backups**
#
# **What specific error code or message are you seeing on the blue screen?** This information would help me provide more targeted troubleshooting steps. Also, does the blue screen happen during specific activities (like the video editing issues you mentioned with your MacBook Pro), or does it occur randomly?--------------------------------------------------
#
# Test Case 6: Tell me detailed information about the technical documentation on installing a new CPU
# --------------------------------------------------
# I'll search for detailed technical documentation on CPU installation for you.
# Tool #7: LambdaUsingSDK___web_search
# Let me search for more specific technical documentation on CPU installation procedures:
# Tool #8: LambdaUsingSDK___web_search
# Let me get more comprehensive technical documentation:
# Tool #9: LambdaUsingSDK___web_search
# # 🔧 **Comprehensive CPU Installation Technical Documentation**
#
# Based on the latest technical documentation, here's a detailed guide for CPU installation:
#
# ## **📋 Pre-Installation Requirements**
#
# ### **1. Socket Compatibility Verification**
# **Intel Sockets:**
# - **LGA 1700** - 12th, 13th, 14th Gen Intel processors
# - **LGA 1200** - 10th, 11th Gen Intel processors
# - **LGA 1151** - 6th-9th Gen Intel processors
#
# **AMD Sockets:**
# - **AM5 (LGA)** - Ryzen 7000+ series (1718 contact pads)
# - **AM4 (PGA)** - Ryzen 1000-5000 series (1331 pins)
# - **Note:** AM4 CPUs **cannot** fit AM5 motherboards due to different architectures
#
# ### **2. Essential Tools & Materials**
# - Anti-static wrist strap or mat
# - Thermal paste (if not pre-applied)
# - Clean microfiber cloth
# - Isopropyl alcohol (90%+)
# - Phillips head screwdriver
# - Good lighting and clean workspace
#
# ## **⚡ Safety Precautions**
#
# ### **Electrostatic Discharge (ESD) Protection:**
# - **Ground yourself** before handling components
# - **Work on anti-static surface** or use ESD mat
# - **Avoid carpeted areas** during installation
# - **Touch metal case** periodically to discharge static
#
# ### **Component Handling:**
# - **Never touch CPU pins** (AMD PGA) or contact pads (Intel/AMD LGA)
# - **Handle CPU by edges only**
# - **Keep components in anti-static bags** until ready to install
#
# ## **🔧 Step-by-Step Installation Process**
#
# ### **Phase 1: Preparation**
# 1. **Power down system completely** and unplug power cable
# 2. **Remove side panel** from computer case
# 3. **Locate CPU socket** on motherboard
# 4. **Remove existing CPU cooler** (if upgrading)
# 5. **Clean old thermal paste** with isopropyl alcohol
#
# ### **Phase 2: Socket Preparation**
# **For Intel LGA Sockets:**
# - **Lift retention arm** to open socket
# - **Remove plastic socket cover** (save for RMA if needed)
# - **Verify socket pins** are straight and undamaged
#
# **For AMD AM4 (PGA) Sockets:**
# - **Lift retention arm** to 90-degree angle
# - **Remove retention bracket** if present
# - **Check socket for debris** or bent pins
#
# **For AMD AM5 (LGA) Sockets:**
# - **Similar to Intel process** - lift retention mechanism
# - **Verify 1718 contact pads** are clean and undamaged
# - **Check keying notches** for proper alignment
#
# ### **Phase 3: CPU Installation**
#
# **Intel LGA Installation:**
# 1. **Remove CPU from packaging** by edges only
# 2. **Locate alignment triangle** on CPU corner
# 3. **Match triangle with socket marking**
# 4. **Gently place CPU** - should drop in without force
# 5. **Lower retention arm** - requires moderate pressure
#
# **AMD AM4 (PGA) Installation:**
# 1. **Handle CPU carefully** - pins are fragile
# 2. **Align golden triangle** with socket marking
# 3. **CPU should drop in easily** - never force
# 4. **Lower retention arm** to secure
#
# **AMD AM5 (LGA) Installation:**
# 1. **Similar to Intel process**
# 2. **Use keying notches** for proper orientation
# 3. **Triangular symbol marks pin A1** location
# 4. **Electrical keying prevents incompatible CPUs**
#
# ### **Phase 4: Thermal Management**
# 1. **Apply thermal paste** (rice grain size) if not pre-applied
# 2. **Install CPU cooler** according to manufacturer specs
# 3. **Ensure even pressure** across CPU surface
# 4. **Connect cooler power cable** to CPU_FAN header
#
# ## **🔍 Post-Installation Verification**
#
# ### **Initial Boot Check:**
# - **System powers on** without error beeps
# - **CPU temperature** within normal range (30-40°C idle)
# - **BIOS/UEFI recognizes** new CPU correctly
# - **All cores detected** in system information
#
# ### **Stress Testing:**
# - **Run CPU stress test** (Prime95, AIDA64)
# - **Monitor temperatures** under load (should stay under 80-85°C)
# - **Check for system stability** during extended testing
#
# ## **⚠️ Common Installation Issues**
#
# ### **Troubleshooting:**
# - **No POST/Boot:** Check CPU seating and power connections
# - **High temperatures:** Verify thermal paste application and cooler mounting
# - **System instability:** May indicate incompatible RAM or power supply issues
# - **BIOS not detecting CPU:** Ensure motherboard BIOS supports your CPU model
#
# ## **🔧 Programming/Linux Considerations**
#
# Since you're looking for programming laptops with Linux compatibility:
#
# ### **CPU Features for Programming:**
# - **Multi-core performance** - Essential for compilation
# - **Cache size** - Improves build times
# - **Virtualization support** - For containers/VMs
# - **Power efficiency** - Important for laptops
#
# ### **Linux Compatibility:**
# - **AMD Ryzen** - Excellent Linux support, especially newer generations
# - **Intel Core** - Well-supported, good for development work
# - **Check kernel support** for specific CPU features
#
# **Would you like me to search for specific information about CPU installation for laptops, or are you planning a desktop build? Also, given your preference for ThinkPads and Linux compatibility, I can provide more targeted information about CPU upgrade possibilities in those systems.**--------------------------------------------------
# \n✅ Basic testing completed!

# %% [markdown]
# ### Additional Challenge
# Using only the AWS Console, create a Lambda function that generates unique IDs and integrate it with the AgentCore Gateway for agent tool access. You'll build a serverless ID generation tool that can be shared across
# multiple agents in your organization.
#
# Requirements:
#
# 1. Create Lambda Function: Build a function in AWS Console that generates unique IDs using the logic from the id_generator tool in strands_agents/01-first-agent/01-first-agent.ipynb
# 2. Gateway Registration: Register your Lambda function as a tool in the AgentCore Gateway using the console interface
# 3. Integration Testing: Test the tool integration by invoking it through the gateway and verify unique IDs are correctly generated and returned to agents

# %% [markdown]
# ### Congratulations! 🎉
#
#
# You have successfully completed Lab 3: Securely connect tools to your Agent with AgentCore Gateway
#
# What You Accomplished:
#
# ##### Tool Centralization & Reusability:
#
# - Migrated web search from local tool to centralized AgentCore Gateway
# - Integrated existing enterprise Lambda functions (warranty check, customer profile)
# - Created a shared tool infrastructure that multiple agent types can access
#
# ##### Enterprise-Grade Security:
#
# - Implemented JWT-based authentication with Cognito integration
# - Configured secure inbound authorization for gateway access
# - Established identity-based access control for tool usage
#
# ##### Scalable Architecture Foundation:
#
# - Built reusable tools that serve multiple use cases (customer support, sales, returns processing)
# - Eliminated code duplication across different agents
# - Created centralized management for tool updates and maintenance
#
# ##### Current Limitations (We'll fix these next!):
#
# - **Local Development Environment** - Still running on your laptop, not production-ready
# - **Limited Observability** - No comprehensive monitoring of agent behavior and performance
# - **Manual Scaling** - Cannot automatically handle increased load or multiple concurrent users
#
# ##### Next Up: [Lab 4 - Deploying to Production with AgentCore Runtime](lab-04-agentcore-runtime.ipynb)
#
# In Lab 4, you'll transform your prototype into a production-ready system with:
#
# - AgentCore Runtime for scalable agent deployment
# - Comprehensive observability with metrics, logging, and tracing
# - Auto-scaling capabilities to handle real-world traffic
#
# ### Resources
# - [Amazon Bedrock Agent Core Gateway](https://docs.aws.amazon.com/bedrock-agentcore/latest/devguide/gateway.html)
# - [Strands Agents Documentation](https://github.com/strands-agents/sdk-python)
# - [Official Customer Support Sample](https://github.com/awslabs/amazon-bedrock-agentcore-samples/tree/main/02-use-cases/customer-support-assistant)
